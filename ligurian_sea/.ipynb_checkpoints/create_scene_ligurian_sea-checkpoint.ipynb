# %%
# Read the numerical model output, make some maps to check the conditions, crop the fields of interest in the areas
# of interest and save them in a netcdf file.

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import pandas as pd
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import geometry as gm

# %%
# To plot maps.
crs = ccrs.PlateCarree()

def plot_background(ax):
    #ax.set_extent(extent_param)
    ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.5)
    #ax.add_feature(cfeature.STATES, linewidth=0.5)
    ax.add_feature(cfeature.BORDERS, linewidth=0.5)
    gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, alpha=0.5)
    gl.top_labels = False
    gl.right_labels = False
    gl.xlabel_style = {'fontsize': 14}
    gl.ylabel_style = {'fontsize': 14}
    return ax

# %%
def crop_field(field,lon,lat,area):
    """
    Function to crop a 2d field over the area specified by the list
    area = [minlon,minlat,maxlon,maxlat]
    """
    valid_indices = np.argwhere((lon>area[0])&(lon<area[2])&(lat>area[1])&(lat<area[3]))
    x_min, y_min = valid_indices.min(axis=0)
    x_max, y_max = valid_indices.max(axis=0)
    return field[x_min:x_max+1, y_min:y_max+1]

# %%
# Set the paths and the file names of the (coupled) oceanic and atmospheric model outputs.
path2atm = '/mnt/storage_unimib/agostino/genoa2014/3CPLD/'
path2oce = '/mnt/storage_unimib/agostino/genoa2014/3CPLD/CPLD_HIS/'

# %%
# Set the instant of interest.
str_instant = '2014-10-10T00:00:00'
# Valid range: from 2014-10-06_00:00:00 to 2014-10-10_00:00:00.

atm_filename = path2atm + 'wrfout_d01_' + str_instant[:10] + '_' + str_instant[11:]
oce_filename = path2oce + 'roms_cpld_his.0025.nc' 
# If str_instant is after '2014-10-07T12:00:00' select the roms_cpld_his.0025.nc file, otherwise use the 
# roms_cpld_his.0020.nc

# %%
# Read the oceanic grid file.
oce_grd_filename = '/mnt/storage_unimib/agostino/genoa2014/3CPLD/spinup/INPUTS/roms_grd.nc'
ds_oce_grd = xr.open_dataset(oce_grd_filename)
lon_oce = ds_oce_grd['lon_rho'].values
lat_oce = ds_oce_grd['lat_rho'].values
mask_oce = ds_oce_grd['mask_rho'].values
angle_oce = ds_oce_grd['angle'][1:,1:].values*np.pi/180

# Read the output files.
ds_oce = xr.open_dataset(oce_filename)
ds_atm = xr.open_dataset(atm_filename)

# Select the right frame in the oceanic output and read the appropriate variables.
ref_instant = np.datetime64(str_instant)
time0 = np.datetime64('2014-09-15T00:00:00') # Time of the initialization of the oceanic output time axis.
time_oce = time0 + ds_oce.time.values.astype('timedelta64[s]')

for hi in range(len(time_oce)):
    instant = time_oce[hi]
    if instant == ref_instant:
        print(instant)
        # Unstagger the current components while reading them.
        uc_mod = 0.5*(ds_oce['u'][hi,-1,1:,:].values + ds_oce['u'][hi,-1,:-1,:].values)
        vc_mod = 0.5*(ds_oce['v'][hi,-1,:,1:].values + ds_oce['v'][hi,-1,:,:-1].values) 
        uc = uc_mod*np.cos(angle_oce) - vc_mod*np.sin(angle_oce)
        vc = uc_mod*np.sin(angle_oce) + vc_mod*np.cos(angle_oce)
        sst_oce = ds_oce['temp'][hi,-1,:,:].values
        
# Select the atmospheric variables of interest.
lon_atm = ds_atm['XLONG'][0].values
lat_atm = ds_atm['XLAT'][0].values
lakemask = ds_atm['LAKEMASK'][0].values
landmask = ds_atm['LANDMASK'][0].values
sst_atm = ds_atm['SST'][0].values
u10_mod = ds_atm['U10'][0].values
v10_mod = ds_atm['V10'][0].values
cosalpha = ds_atm['COSALPHA'][0].values
sinalpha = ds_atm['SINALPHA'][0].values

seamask = 1 - lakemask - landmask
seamask_nan = np.where(seamask==1,seamask,np.nan)
u10 = u10_mod*cosalpha - v10_mod*sinalpha
v10 = u10_mod*sinalpha + v10_mod*cosalpha
# Out:
# 2014-10-10T00:00:00

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(1, 1, 1, projection=crs)
plot_background(ax)
pc = plt.pcolormesh(lon_oce,lat_oce,np.sqrt(uc**2+vc**2)/mask_oce[1:,1:])
step = 15
qv = plt.quiver(lon_oce[::step,::step],lat_oce[::step,::step],uc[::step,::step],vc[::step,::step],
                color='w',scale=15)

plt.title(str_instant + ' ocean surface current [m/s]', fontsize=16)
plt.xlabel('Longitude',fontsize=14)
plt.ylabel('Latitude',fontsize=14)
plt.colorbar(pc)
# Out:
# <ipython-input-69-cd3d4d3c3f7b>:4: RuntimeWarning: divide by zero encountered in true_divide
#   pc = plt.pcolormesh(lon_oce,lat_oce,np.sqrt(uc**2+vc**2)/mask_oce[1:,1:])
# <ipython-input-69-cd3d4d3c3f7b>:4: RuntimeWarning: invalid value encountered in true_divide
#   pc = plt.pcolormesh(lon_oce,lat_oce,np.sqrt(uc**2+vc**2)/mask_oce[1:,1:])

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(1, 1, 1, projection=crs)
plot_background(ax)
pc = plt.pcolormesh(lon_oce,lat_oce,sst_oce/mask_oce,vmin=19.5,vmax=24.5)
step = 15
#qv = plt.quiver(lon_oce[::step,::step],lat_oce[::step,::step],uc[::step,::step],vc[::step,::step],
#                color='w',scale=15)

plt.title(str_instant + ' ocean surface temperature [°C]', fontsize=16)
plt.xlabel('Longitude',fontsize=14)
plt.ylabel('Latitude',fontsize=14)
plt.colorbar(pc)
# Out:
# <ipython-input-70-6f926596f851>:4: RuntimeWarning: invalid value encountered in true_divide
#   pc = plt.pcolormesh(lon_oce,lat_oce,sst_oce/mask_oce,vmin=19.5,vmax=24.5)

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(1, 1, 1, projection=crs)
plot_background(ax)
pc = plt.pcolormesh(lon_atm,lat_atm,(sst_atm-273.15)/seamask,vmin=19.5,vmax=24.5)
step = 15

plt.title(str_instant + ' ocean surface temperature\nfrom atmospheric model [°C]', fontsize=16)
plt.xlabel('Longitude',fontsize=14)
plt.ylabel('Latitude',fontsize=14)
plt.colorbar(pc)
# Out:
# <ipython-input-71-098fd6124bdd>:4: RuntimeWarning: divide by zero encountered in true_divide
#   pc = plt.pcolormesh(lon_atm,lat_atm,(sst_atm-273.15)/seamask,vmin=19.5,vmax=24.5)

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(1, 1, 1, projection=crs)
plot_background(ax)
pc = plt.pcolormesh(lon_atm,lat_atm,np.sqrt(u10**2+v10**2)*seamask_nan)
step = 15

plt.title(str_instant + ' wind speed [m/s]', fontsize=16)
plt.xlabel('Longitude',fontsize=14)
plt.ylabel('Latitude',fontsize=14)
plt.colorbar(pc)

# %%
# Compute the wind divergence.
div = gm.div_sphere(u10,v10,lon_atm,lat_atm)

fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(1, 1, 1, projection=crs)
plot_background(ax)
pc = plt.pcolormesh(lon_atm,lat_atm,div*seamask_nan,vmin=-1e-3,vmax=1e-3,cmap='coolwarm')
step = 15

plt.title(str_instant + ' wind divergence [1/s]', fontsize=16)
plt.xlabel('Longitude',fontsize=14)
plt.ylabel('Latitude',fontsize=14)
plt.colorbar(pc)

# %%
# Crop the relevant areas and save the netcdf file.
# Different areas are defined, based on some variables.
    # Strong wind convergence area.
minlon = 7.25; minlat = 42.25; maxlon = minlon+0.5; maxlat = minlat+0.5
area_name = 'strong_wind_conv'
minlon = 7; minlat = 41.5; maxlon = 10.2; maxlat = 44.25
area_name = 'domain'

area = [minlon,minlat,maxlon,maxlat]

# Oceanic variables.
lon_c = crop_field(lon_oce,lon_oce,lat_oce,area)
lat_c = crop_field(lat_oce,lon_oce,lat_oce,area)
uc_c = crop_field(uc,lon_oce,lat_oce,area)
vc_c = crop_field(vc,lon_oce,lat_oce,area)
# Atmospheric variables (the cropped lon and lat are the same as for the oceanic model).
wind10_div_c = crop_field(div*seamask_nan,lon_atm,lat_atm,area)
u10_c = crop_field(u10*seamask_nan,lon_atm,lat_atm,area)
v10_c = crop_field(v10*seamask_nan,lon_atm,lat_atm,area)
sst_c = crop_field(sst_atm*seamask_nan,lon_atm,lat_atm,area)

# Create a dataset.
ds = xr.Dataset(
    data_vars = dict(
        lon=(["x","y"],lon_c),    
        lat=(["x","y"],lat_c),    
        uc=(["x","y"],uc_c,dict(units='m/s')),    
        vc=(["x","y"],vc_c,dict(units='m/s')),    
        sst=(["x","y"],sst_c,dict(units='K')),    
        u10=(["x","y"],u10_c,dict(units='m/s')),    
        v10=(["x","y"],v10_c,dict(units='m/s')),    
        wind_div=(["x","y"],wind10_div_c,dict(units='1/s'))    
    ),
    attrs=dict(
        ref_time = str_instant
    )
)

# Save the netcdf.
strfile = 'ligurian_sea_'+str_instant+'_area_'+area_name+'.nc'
ds.to_netcdf(strfile)

# %%
# Plot some maps of the cropped area.
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(1, 1, 1, projection=crs)
plot_background(ax)
pc = plt.pcolormesh(lon_c,lat_c,np.sqrt(uc_c**2+vc_c**2))
step = 3
qv = plt.quiver(lon_c[::step,::step],lat_c[::step,::step],uc_c[::step,::step],vc_c[::step,::step],
                color='w',scale=10)

plt.title(str_instant + ' ocean surface current [m/s]', fontsize=16)
plt.xlabel('Longitude',fontsize=14)
plt.ylabel('Latitude',fontsize=14)
plt.colorbar(pc)
figure_name = 'ligurian_sea_'+str_instant+'_area_'+area_name+'_ocean_surface_currents.png'
plt.savefig(figure_name,bbox_inches='tight')

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(1, 1, 1, projection=crs)
plot_background(ax)
pc = plt.pcolormesh(lon_c,lat_c,sst_c-273.15)
step = 3
qv = plt.quiver(lon_c[::step,::step],lat_c[::step,::step],u10_c[::step,::step],v10_c[::step,::step],
                color='w',scale=100)
#ct = plt.contour(lon_c,lat_c,np.sqrt(u10_c**2+v10_c**2),colors='r')
plt.title(str_instant + ' SST [°C] and sfc wind', fontsize=16)
plt.xlabel('Longitude',fontsize=14)
plt.ylabel('Latitude',fontsize=14)
plt.colorbar(pc)
figure_name = 'ligurian_sea_'+str_instant+'_area_'+area_name+'_sst_and_sfc_wind.png'
plt.savefig(figure_name,bbox_inches='tight')
